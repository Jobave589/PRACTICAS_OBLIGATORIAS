# %% [markdown]
# ## **Lo más importante**
#
#  + Matemáticas
#  + Python
#  + SQL
#
# ![Captura de pantalla 2024-10-20 201825.png](attachment:d0fd96da-bd3b-4c93-b3d1-a7d39b509e45.png)
#
# Otro tema importante es el de *Business Intelligence*
#
# Si tienes dudas, puedes escribirme a: <a href="mailto:alberto.romero@thebridgeschool.es" style="color: blue;">alberto.romero@thebridgeschool.es</a>
#
# Y en esta página se aprende mucho de machine learning: <a href="https://www.kaggle.com/" style="color:blue;">**página con ML**</a>

# %% [markdown]
# | **Ramp Up** | **Data Analysis** | **Machine Learning** | **Data & Business** |
# |---------------|---------------|---------------|---------------|
# |  Python | EDA | Supervised | Productivización |
# | Estadística | R | Non supervised | Storytelling |
# | SQL | Feat. Eng. | Deep Learning | API |

# %% [markdown]
# $$\sqrt{3x-1}+(1+x)^2$$
